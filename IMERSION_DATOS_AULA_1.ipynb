# %% [markdown]
# <a href="https://colab.research.google.com/github/KarinaRmzG/Inmersion-de-datos-con-Python/blob/main/IMERSION_DATOS_AULA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Clase 1**
#
# *Conexión de google colab con drive*

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/Curso Python/inmuebles_bogota.csv')
inmuebles.head() #Mostrando los primeros 5 registros del dataset
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape #Contar registros (filas,columnas)
# Out:
# (9520, 8)

# %%
inmuebles.columns #Mostrando informacion de las columnas del dataset
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños':'Banos','Área':'Area'} #creacion de un diccionario
inmuebles = inmuebles.rename(columns=columnas) #asignacion del diccionario en las columnas
inmuebles.sample(10) #mostrar 10  registros del dataset de forma aleatoria
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 7184  Apartamento        Apartamento en venta en Kennedy             3      1
# 8246  Apartamento   Apartamento en venta en Gran Granada             4      2
# 3156  Apartamento  Apartamento en venta en La Candelaria             3      5
# 154   Apartamento       Apartamento en venta en Cedritos             3      3
# 1218  Apartamento           Apartamento en venta en Suba             3      3
# 1062  Apartamento       Apartamento en venta en Engativa             3      3
# 5233  Apartamento        Apartamento en venta en Usaquén             3      2
# 2810  Apartamento    Apartamento en venta en Chico Norte             1      2
# 6166         Casa              Casa en venta en Fontibón             6      3
# 81    Apartamento        Apartamento en venta en Mazuren             3      3
#
#       Area         Barrio                                 UPZ            Valor
# 7184    48        Kennedy                     Kennedy Central    $ 135.000.000
# 8246    71   Gran Granada                        Garcés Navas    $ 260.000.000
# 3156   357  La Candelaria                       La Candelaria  $ 4.800.000.000
# 154    108       Cedritos                             Usaquén    $ 503.000.000
# 1218   125           Suba                                Suba    $ 920.000.000
# 1062    90       Engativa                            Engativá    $ 470.000.000
# 5233    73        Usaquén                             Usaquén    $ 310.000.000
# 2810    66    Chico Norte  CHAPINERO: Chicó Lago + El Refugio    $ 790.000.000
# 6166   314       Fontibón                            Fontibón    $ 700.000.000
# 81      92        Mazuren                            El Prado    $ 372.000.000
